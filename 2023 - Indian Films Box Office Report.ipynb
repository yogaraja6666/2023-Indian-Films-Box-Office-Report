# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# try:
#     response = requests.get("https://www.imdb.com/list/ls562330283/")
#     soup = BeautifulSoup(response.content,"html.parser")
#     print("s")
# except Exception as e:
#     print(e)

# %% [markdown]
# movies_data = soup.findAll("div",attrs={"class":"lister-item mode-detail"})

# %% [markdown]
# movie_name =[]
# year = []
# runtime = []
# genre = []

# %% [markdown]
# for i in movies_data:
#     name = i.h3.a.text
#     movie_name.append(name)
#     yr = i.h3.find('span',class_="lister-item-year text-muted unbold").text.replace("(","").replace(")","").replace("I","")
#     year.append(yr)
#     rt = i.p.find("span",class_="runtime").text
#     runtime.append(rt)
#     gr = i.p.find("span",class_="genre").text.replace('\n','').replace(' ','')
#     genre.append(gr)

# %% [markdown]
# data = {
#     'Movie Name': movie_name,
#     'Year': year,
#     'Runtime': runtime,
#     'Genre': genre
# }
#
#
# df = pd.DataFrame(data)
#
# df.to_csv('movie_data.csv', index=False)
# print("Data saved to movie_data.csv")

# %%
df = pd.read_csv("movie_data.csv")
df
# Out:
#                          Movie Name  Year  Runtime                      Genre  \
# 0                             Jawan  2023  169 min            Action,Thriller
# 1                           Pathaan  2023  146 min  Action,Adventure,Thriller
# 2                           Gadar 2  2023  170 min     Action,Adventure,Drama
# 3                            Jailer  2023  168 min        Action,Comedy,Crime
# 4                         Adipurush  2023  179 min     Action,Adventure,Drama
# 5   Rocky Aur Rani Kii Prem Kahaani  2023  168 min        Comedy,Drama,Family
# 6         Ponniyin Selvan: Part Two  2023  164 min     Action,Adventure,Drama
# 7                            Varisu  2023  169 min               Action,Drama
# 8                  The Kerala Story  2023  138 min                      Drama
# 9                  Waltair Veerayya  2023  155 min               Action,Drama
# 10                            OMG 2  2023  156 min               Comedy,Drama
# ...
